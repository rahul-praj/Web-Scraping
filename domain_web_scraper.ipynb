# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup
import requests
import os
import re
import scrapy
from scrapy.crawler import CrawlerProcess
from scrapy.utils.project import get_project_settings

# %% [markdown]
# ### Create function to scrape data from domain

# %%
class DomainSpider(scrapy.Spider):
    name = 'domain'
    
    def start_requests(self):
        number = self.number
        street = self.street
        suburb = self.suburb
        state = self.state
        postcode = self.postcode
        
        url = f'https://www.domain.com.au/property-profile/{number}-{street}-{suburb}-{state}-{postcode}'
        yield scrapy.Request(url=url, callback=self.parse, meta={
            'number': number,
            'street': street,
            'suburb': suburb,
            'state': state,
            'postcode': postcode
        })
    
    def parse(self, response):
        number = response.meta['number']
        street = response.meta['street']
        suburb = response.meta['suburb']
        state = response.meta['state']
        postcode = response.meta['postcode']
        
        dates = []
        events = []
        prices = []
        
        if response.status != 200:
            dates.append(None)
            events.append(None)
            prices.append(None)
        else:
            property_history_section = response.css('.property-history')
            rows = property_history_section.css('tbody tr')
            
            for row in rows:
                date = row.css('td.date span::text').get()
                event = row.css('td.event::text').get()
                price = row.css('td.price::text').get()
                
                dates.append(date)
                events.append(event)
                prices.append(price)
                
            scraped_data= pd.DataFrame({
                'number': number,
                'street': street,
                'suburb': suburb,
                'state': state,
                'postcode': postcode,
                'dates': dates,
                'events': events,
                'prices': prices
            })
            
        yield scraped_data

# %% [markdown]
# ### Read in registry data

# %%
cwd = os.getcwd()
file_path = os.path.join(cwd, 'stra_property_register.csv')

df = pd.read_csv(file_path)
df
# Out:
#              AddressID         TypeOfAccomodation RegistrantOwnershipStatus  \
# 0           PID-STRA-1             Dual Occupancy                     Owner
# 1         PID-STRA-100  Residential Flat Building                    Tenant
# 2       PID-STRA-10000         Secondary Dwelling                     Owner
# 3       PID-STRA-10001             Dwelling House                     Owner
# 4      PID-STRA-1000-1             Dwelling House                     Owner
# ...                ...                        ...                       ...
# 50305    PID-STRA-9995     Semi-Detached Dwelling                     Owner
# 50306  PID-STRA-9996-2         Secondary Dwelling                     Owner
# 50307    PID-STRA-9997             Dwelling House                     Owner
# 50308    PID-STRA-9998             Dwelling House                     Owner
# 50309    PID-STRA-9999  Residential Flat Building                     Owner
#
#       HostingType                             FULLADDRESS PropertyStatus  \
# 0      Non-Hosted         853 CUMBERDOON WAY WALGETT 2832  De-Registered
# 1          Hosted       38 45 BONAR STREET ARNCLIFFE 2205        Blocked
# 2          Hosted        63 KITCHENER STREET ST IVES 2075     Registered
# 3      Non-Hosted             1 SUNSET STRIP MANYANA 2539     Registered
# 4          Hosted  117 CUDGERA CREEK ROAD BURRINGBAR 2483     Registered
# ...           ...                                     ...            ...
# 50305      Hosted            23 GOLDING STREET YAMBA 2464     Registered
# 50306      Hosted        3 WASHINGTON STREET TINONEE 2430     Registered
# 50307      Hosted        34 ARCHER CRESCENT MARYLAND 2287     Registered
# 50308      Hosted       101 BUNGAN HEAD ROAD NEWPORT 2106        Blocked
# 50309  Non-Hosted   5 65 CURLEWIS STREET BONDI BEACH 2026     Registered
#
#         EndDateCurRenYr       Suburb  PostCode DeregistrationDate  \
# 0      31/10/2022 23:59      WALGETT    2832.0     4/03/2022 0:00
# 1      31/10/2022 23:59    ARNCLIFFE    2205.0    22/09/2022 0:00
# 2      31/10/2023 23:59      ST IVES    2075.0                NaN
# 3      31/10/2023 23:59      MANYANA    2539.0                NaN
# 4      31/10/2023 23:59   BURRINGBAR    2483.0                NaN
# ...                 ...          ...       ...                ...
# 50305  31/10/2023 23:59        YAMBA    2464.0                NaN
# 50306  31/10/2023 23:59      TINONEE    2430.0                NaN
# 50307  31/10/2023 23:59     MARYLAND    2287.0    31/01/2023 4:38
# 50308  31/10/2022 23:59      NEWPORT    2106.0                NaN
# 50309  31/10/2023 23:59  BONDI BEACH    2026.0                NaN
#
#                     CouncilName   PropertySubStatus HostOwnership  \
# 0                    CUMBERLAND                Sold         Owner
# 1               BAYSIDE COUNCIL  Unpaid Renewal Fee        Tenant
# 2           KU-RING-GAI COUNCIL              Active         Owner
# 3       SHOALHAVEN CITY COUNCIL              Active         Owner
# 4           TWEED SHIRE COUNCIL              Active         Owner
# ...                         ...                 ...           ...
# 50305   CLARENCE VALLEY COUNCIL              Active         Owner
# 50306         MID-COAST COUNCIL              Active         Owner
# 50307    NEWCASTLE CITY COUNCIL              Active         Owner
# 50308  NORTHERN BEACHES COUNCIL  Unpaid Renewal Fee         Owner
# 50309          WAVERLEY COUNCIL              Active         Owner
#
#       DevtConsentNumber IsDAissued
# 0                   NaN       True
# 1                   NaN        NaN
# 2                   NaN      False
# 3                   NaN      False
# 4          DA18/0569.01      False
# ...                 ...        ...
# 50305               NaN      False
# 50306               NaN      False
# 50307               NaN      False
# 50308               NaN      False
# 50309               NaN      False
#
# [50310 rows x 15 columns]

# %% [markdown]
# ### Data processing

# %% [markdown]
# ##### Filter data for non-hosted and registered STRA only

# %%
df = df[(df.HostingType == 'Non-Hosted') & (df.PropertyStatus == 'Registered')]
df.reset_index(inplace=True)
addresses = df.FULLADDRESS.str.lower()
addresses.fillna("No Address", inplace=True)

# %% [markdown]
# ##### Use regex to extract address components

# %%
house_number_regex = r'^[a-z]*\s*\#*[0-9]*\,*\s*[lot\s\d+]*\d+(\s|/|\w+)[0-9]*'
street_name_regex = r'\b\w+\s(?:st(?:reet)?|r(?:oa)?d|lane|ln|circuit|dr(?:ive)?|ave(?:nue)?|pl(?:ace)?|boulevard|way|terrace|circle|court|parkway|strip)\b'
# suburb_regex = fr'(?<!{street_name_regex})\s\w+\s\w*\d{4}$'
postcode_regex = r'\d{4}$'

house_numbers = []
street_names = []
postcodes = []

for count, address in enumerate(addresses):
    try:
        house_number = re.search(house_number_regex, address).group().strip()
        house_numbers.append(house_number)
    except:
        house_numbers.append("")
        
for count, address in enumerate(addresses):
    try:
        street_name = re.search(street_name_regex, address).group().strip()
        street_names.append(street_name)
    except:
        street_names.append("")
        continue
        
for address in addresses:
    try:
        postcode = re.search(postcode_regex, address).group().strip()
        postcodes.append(postcode)
    except:
        postcodes.append("")
        continue
    
suburbs = df.Suburb.str.lower()
    
address_processed = pd.DataFrame({
    'house_num': house_numbers,
    'street_name': street_names,
    'suburb': suburbs,
    'postcode': postcodes
})

address_processed
# Out:
#       house_num      street_name        suburb postcode
# 0             1     sunset strip       manyana     2539
# 1         1 230    palmer street  darlinghurst     2010
# 2            30    cooinda place         kiama     2533
# 3           305  katoomba street      katoomba     2780
# 4            96       heath road  pretty beach     2257
# ...         ...              ...           ...      ...
# 27544        63      sandy place    long beach     2536
# 27545        72    moncur street     woollahra     2025
# 27546      1 29  leofrene avenue  marrickville     2204
# 27547        43   warners avenue   bondi beach     2026
# 27548      5 65  curlewis street   bondi beach     2026
#
# [27549 rows x 4 columns]

# %% [markdown]
# ##### Additional processing to ensure data is formatted correctly when passed through the scraping function

# %%
address_processed.street_name.replace(['\srd$'], " road", regex=True, inplace=True)
address_processed.street_name.replace(['\sst$'], " street", regex=True, inplace=True)
address_processed.street_name.replace(['\save$'], " avenue", regex=True, inplace=True)
address_processed.street_name.replace(['\sln$'], " lane", regex=True, inplace=True)
address_processed.street_name.replace(['\spl$'], " place", regex=True, inplace=True)

address_processed.street_name.replace(['\s'], "-", regex=True, inplace=True)
address_processed.suburb.replace(['\s'], "-", regex=True, inplace=True)
address_processed.house_num.replace(['\s'], "-", regex=True, inplace=True)

# %%
address_processed
# Out:
#       house_num      street_name        suburb postcode
# 0             1     sunset-strip       manyana     2539
# 1         1-230    palmer-street  darlinghurst     2010
# 2            30    cooinda-place         kiama     2533
# 3           305  katoomba-street      katoomba     2780
# 4            96       heath-road  pretty-beach     2257
# ...         ...              ...           ...      ...
# 27544        63      sandy-place    long-beach     2536
# 27545        72    moncur-street     woollahra     2025
# 27546      1-29  leofrene-avenue  marrickville     2204
# 27547        43   warners-avenue   bondi-beach     2026
# 27548      5-65  curlewis-street   bondi-beach     2026
#
# [27549 rows x 4 columns]

# %% [markdown]
# ### Run the web scraper

# %%
process = CrawlerProcess(get_project_settings())

for i in range(len(address_processed)):
    try:
        process.crawl(DomainSpider, number=address_processed.house_num[i], street=address_processed.street_name[i], suburb=address_processed.suburb[i], state='nsw', postcode=address_processed.postcode[i])
    except Exception as e:
        print(f"Error processing row {i}: {e}")

# start the scrapy engine
process.start()
# Out:
# 2023-05-05 19:11:52 [scrapy.utils.log] INFO: Scrapy 2.6.3 started (bot: scrapybot)
# 2023-05-05 19:11:52 [scrapy.utils.log] INFO: Versions: lxml 4.6.3.0, libxml2 2.9.10, cssselect 1.1.0, parsel 1.6.0, w3lib 2.0.1, Twisted 22.4.0, Python 3.6.8 (default, Apr 16 2020, 01:36:27) - [GCC 8.3.1 20191121 (Red Hat 8.3.1-5)], pyOpenSSL 23.1.1 (OpenSSL 3.1.0 14 Mar 2023), cryptography 40.0.2, Platform Linux-4.18.0-193.14.2.el8_2.x86_64-x86_64-with-centos-8.2.2004-Core
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.epollreactor.EPollReactor
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 9df05903dd93fbc4
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 7c400b66a57d870d
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6024
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: cd9d75d4f3ae63e7
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6025
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 2db785b38c30dc4a
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6026
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 2e8cb04fb6178ced
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6027
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: ac8a7220d087a65b
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6028
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 87c7ca69ba555388
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6029
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 6730b057847bc18c
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6030
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 0d7ab10162c9dd25
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6031
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: b0d2e0c3e8e7de5a
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6032
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: d5287ce4d08880bb
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6033
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 5c0483456c884d45
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6034
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: ff6267ab9170204a
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6035
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: f8b85cce04326ad6
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6036
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: a3628a0420ca8e88
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6037
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 8bf5ce3fdc6557ef
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6038
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 08129cfaa21d8a88
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6039
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: c05ce01f74a8ffcb
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6040
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 82e5b807d3ddf213
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6041
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 11bc07f7cffd3e02
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6042
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: fc408ad16aa96cbb
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6043
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: ef6aa68d465e83eb
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6044
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 2171065a5200fa2b
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6045
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 59f135e7b99b94e9
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:52 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:52 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6046
# 2023-05-05 19:11:52 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:52 [scrapy.extensions.telnet] INFO: Telnet Password: 5a715d8e9dd058e9
# 2023-05-05 19:11:52 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:53 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:53 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:53 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:53 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:53 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:53 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6047
# 2023-05-05 19:11:53 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:53 [scrapy.extensions.telnet] INFO: Telnet Password: 268e323b018fbc2d
# 2023-05-05 19:11:53 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:53 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
# ...
#     result = f(*args, **kw)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/pydispatch/robustapply.py", line 55, in robustApply
#     return receiver(*arguments, **named)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/extensions/telnet.py", line 65, in start_listening
#     self.port = listen_tcp(self.portrange, self.host, self)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/reactor.py", line 23, in listen_tcp
#     return reactor.listenTCP(x, factory, interface=host)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/posixbase.py", line 565, in listenTCP
#     p.startListening()
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1336, in startListening
#     raise CannotListenError(self.interface, self.port, le)
# twisted.internet.error.CannotListenError: Couldn't listen on 127.0.0.1:6073: [Errno 98] Address already in use.
# 2023-05-05 19:11:55 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:55 [scrapy.extensions.telnet] INFO: Telnet Password: 36ac68276c405808
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:55 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:55 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:55 [scrapy.utils.signal] ERROR: Error caught on signal handler: <bound method TelnetConsole.start_listening of <scrapy.extensions.telnet.TelnetConsole object at 0x7fda579d17f0>>
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1334, in startListening
#     skt.bind(addr)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/defer.py", line 169, in maybeDeferred_coro
#     result = f(*args, **kw)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/pydispatch/robustapply.py", line 55, in robustApply
#     return receiver(*arguments, **named)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/extensions/telnet.py", line 65, in start_listening
#     self.port = listen_tcp(self.portrange, self.host, self)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/reactor.py", line 23, in listen_tcp
#     return reactor.listenTCP(x, factory, interface=host)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/posixbase.py", line 565, in listenTCP
#     p.startListening()
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1336, in startListening
#     raise CannotListenError(self.interface, self.port, le)
# twisted.internet.error.CannotListenError: Couldn't listen on 127.0.0.1:6073: [Errno 98] Address already in use.
# 2023-05-05 19:11:55 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:55 [scrapy.extensions.telnet] INFO: Telnet Password: b3341176b7aa23a2
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:55 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:55 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:55 [scrapy.utils.signal] ERROR: Error caught on signal handler: <bound method TelnetConsole.start_listening of <scrapy.extensions.telnet.TelnetConsole object at 0x7fda579eb5c0>>
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1334, in startListening
#     skt.bind(addr)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/defer.py", line 169, in maybeDeferred_coro
#     result = f(*args, **kw)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/pydispatch/robustapply.py", line 55, in robustApply
#     return receiver(*arguments, **named)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/extensions/telnet.py", line 65, in start_listening
#     self.port = listen_tcp(self.portrange, self.host, self)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/reactor.py", line 23, in listen_tcp
#     return reactor.listenTCP(x, factory, interface=host)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/posixbase.py", line 565, in listenTCP
#     p.startListening()
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1336, in startListening
#     raise CannotListenError(self.interface, self.port, le)
# twisted.internet.error.CannotListenError: Couldn't listen on 127.0.0.1:6073: [Errno 98] Address already in use.
# 2023-05-05 19:11:55 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:55 [scrapy.extensions.telnet] INFO: Telnet Password: 144a8aa5ae48c07f
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:55 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:55 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:55 [scrapy.utils.signal] ERROR: Error caught on signal handler: <bound method TelnetConsole.start_listening of <scrapy.extensions.telnet.TelnetConsole object at 0x7fda579852e8>>
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1334, in startListening
#     skt.bind(addr)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/defer.py", line 169, in maybeDeferred_coro
#     result = f(*args, **kw)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/pydispatch/robustapply.py", line 55, in robustApply
#     return receiver(*arguments, **named)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/extensions/telnet.py", line 65, in start_listening
#     self.port = listen_tcp(self.portrange, self.host, self)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/reactor.py", line 23, in listen_tcp
#     return reactor.listenTCP(x, factory, interface=host)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/posixbase.py", line 565, in listenTCP
#     p.startListening()
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1336, in startListening
#     raise CannotListenError(self.interface, self.port, le)
# twisted.internet.error.CannotListenError: Couldn't listen on 127.0.0.1:6073: [Errno 98] Address already in use.
# 2023-05-05 19:11:55 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:55 [scrapy.extensions.telnet] INFO: Telnet Password: 647fa5cf841d0b0e
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2023-05-05 19:11:55 [scrapy.core.engine] INFO: Spider opened
# 2023-05-05 19:11:55 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2023-05-05 19:11:55 [scrapy.utils.signal] ERROR: Error caught on signal handler: <bound method TelnetConsole.start_listening of <scrapy.extensions.telnet.TelnetConsole object at 0x7fda5799cfd0>>
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1334, in startListening
#     skt.bind(addr)
# OSError: [Errno 98] Address already in use
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/defer.py", line 169, in maybeDeferred_coro
#     result = f(*args, **kw)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/pydispatch/robustapply.py", line 55, in robustApply
#     return receiver(*arguments, **named)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/extensions/telnet.py", line 65, in start_listening
#     self.port = listen_tcp(self.portrange, self.host, self)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/scrapy/utils/reactor.py", line 23, in listen_tcp
#     return reactor.listenTCP(x, factory, interface=host)
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/posixbase.py", line 565, in listenTCP
#     p.startListening()
#   File "/home/rprajapati/.local/lib/python3.6/site-packages/twisted/internet/tcp.py", line 1336, in startListening
#     raise CannotListenError(self.interface, self.port, le)
# twisted.internet.error.CannotListenError: Couldn't listen on 127.0.0.1:6073: [Errno 98] Address already in use.
# 2023-05-05 19:11:55 [scrapy.crawler] INFO: Overridden settings:
# {}
# 2023-05-05 19:11:55 [scrapy.extensions.telnet] INFO: Telnet Password: 8f43ed3a96821a0f
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2023-05-05 19:11:55 [scrapy.middleware] INFO: Enabled item pipelines:
# []
